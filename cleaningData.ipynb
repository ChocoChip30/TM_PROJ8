# %%
import pandas as pd
import numpy as np

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import nltk

# %%
df = pd.read_csv('amazon_df_final.csv')
df.head()
# Out:
#                                                title  \
# 0  Nakd Fruit & Nut Bar Variety Pack - Vegan - He...
# 1  TREK High Protein Flapjack Cocoa Oat - Gluten ...
# 2  Nourish Organic Cacao Coconut Macaroons - Keto...
# 3  Eat Natural Protein Bars, Protein Packed Peanu...
# 4  HappyHome Ultimate Hampers Gluten Free Hamper ...
#
#                                          ingredients  \
# 0  Cocoa Orange Ingredients: Dates 40%, CASHEWS 4...
# 1  Gluten free OATS (25%), Rice syrup, SOYA prote...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  url
# 0  https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Cas...
# 1  https://amazon.co.uk/Trek-Cocoa-Oat-Protein-Fl...
# 2  https://amazon.co.uk/Nourish-Cacao-Macaroons-1...
# 3  https://amazon.co.uk/Natural-Protein-Packed-Pa...
# 4  https://amazon.co.uk/HappyHome-Ultimate-Hamper...

# %%
df.iloc[0].tolist()
# Out:
# ['Nakd Fruit & Nut Bar Variety Pack - Vegan - Healthy Snack - Gluten Free - 35g x 18 bars',
#  'Cocoa Orange Ingredients: Dates 40%, CASHEWS 40%, Raisins 14%, Cocoa 5%, Orange oil, Natural flavouring. Blueberry Muffin Ingredients: Dates 58%, CASHEWS 15%, Raisins 15%, ALMONDS 10%, Blueberries 2, Natural flavouring. Salted Caramel Ingredients: Dates 54%, Raisins 21%, CASHEWS 12%, PEANUTS 12%, sea salt 0,4%, Natural flavouring. Peanut Delight Ingredients: Dates 53%, PEANUTS 46%, Sea salt, Natural flavouring. Berry Delight Ingredients: Dates 49%, CASHEWS 30%, Raisins 17%, Raspberries 3%, Natural flavouring. Cocoa Delight Ingredients: Dates 48%,CASHEWS 30%, Raisins 16%, Cocoa 6%, Natural flavouring.',
#  'https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Case/dp/B07LFRLNVM/ref=sr_1_1?crid=2G1IQMWSJ30CR&keywords=gluten+free+snacks&qid=1705342939&sprefix=gluten+free+snacks%2Caps%2C271&sr=8-1']

# %%
df['title'] = df['title'].str.lower()
df['ingredients'] = df['ingredients'].str.lower()

# %%
df.head()
# Out:
#                                                title  \
# 0  nakd fruit & nut bar variety pack - vegan - he...
# 1  trek high protein flapjack cocoa oat - gluten ...
# 2  nourish organic cacao coconut macaroons - keto...
# 3  eat natural protein bars, protein packed peanu...
# 4  happyhome ultimate hampers gluten free hamper ...
#
#                                          ingredients  \
# 0  cocoa orange ingredients: dates 40%, cashews 4...
# 1  gluten free oats (25%), rice syrup, soya prote...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  url
# 0  https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Cas...
# 1  https://amazon.co.uk/Trek-Cocoa-Oat-Protein-Fl...
# 2  https://amazon.co.uk/Nourish-Cacao-Macaroons-1...
# 3  https://amazon.co.uk/Natural-Protein-Packed-Pa...
# 4  https://amazon.co.uk/HappyHome-Ultimate-Hamper...

# %%
def preprocess_text(text):
    # Replace specific phrases with a single token
    text = text.replace("gluten free", "glutenfree")
    text = text.replace("allergen free", "allergenfree")
    return text

# %%
def extract_words(text):
    if pd.isna(text):  # Check for NaN values
        return []

    # Preprocess the text to handle specific phrases
    text = preprocess_text(text)
    
    # Use NLTK's word_tokenize to handle phrases
    words = word_tokenize(text)
    return words

# %%
# Apply the custom function to create a new column for each original column
df['word_list_column1'] = df['title'].apply(extract_words)
df['word_list_column2'] = df['ingredients'].apply(extract_words)

# Combine the lists from both columns into a new column
df['final_word_list'] = df['word_list_column1'] + df['word_list_column2']

df = df.drop(['word_list_column1', 'word_list_column2'], axis=1)
df.head()
# Out:
#                                                title  \
# 0  nakd fruit & nut bar variety pack - vegan - he...
# 1  trek high protein flapjack cocoa oat - gluten ...
# 2  nourish organic cacao coconut macaroons - keto...
# 3  eat natural protein bars, protein packed peanu...
# 4  happyhome ultimate hampers gluten free hamper ...
#
#                                          ingredients  \
# 0  cocoa orange ingredients: dates 40%, cashews 4...
# 1  gluten free oats (25%), rice syrup, soya prote...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  url  \
# 0  https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Cas...
# 1  https://amazon.co.uk/Trek-Cocoa-Oat-Protein-Fl...
# 2  https://amazon.co.uk/Nourish-Cacao-Macaroons-1...
# 3  https://amazon.co.uk/Natural-Protein-Packed-Pa...
# 4  https://amazon.co.uk/HappyHome-Ultimate-Hamper...
#
#                                      final_word_list
# 0  [nakd, fruit, &, nut, bar, variety, pack, -, v...
# 1  [trek, high, protein, flapjack, cocoa, oat, -,...
# 2  [nourish, organic, cacao, coconut, macaroons, ...
# 3  [eat, natural, protein, bars, ,, protein, pack...
# 4  [happyhome, ultimate, hampers, glutenfree, ham...

# %%
def clean_and_lower(word_list):
    cleaned_list = [word.lower() for word in word_list if not word.isdigit()]
    return cleaned_list

# Apply the cleaning function to the final word list column
df['final_word_list'] = df['final_word_list'].apply(clean_and_lower)
df.head()
# Out:
#                                                title  \
# 0  nakd fruit & nut bar variety pack - vegan - he...
# 1  trek high protein flapjack cocoa oat - gluten ...
# 2  nourish organic cacao coconut macaroons - keto...
# 3  eat natural protein bars, protein packed peanu...
# 4  happyhome ultimate hampers gluten free hamper ...
#
#                                          ingredients  \
# 0  cocoa orange ingredients: dates 40%, cashews 4...
# 1  gluten free oats (25%), rice syrup, soya prote...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  url  \
# 0  https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Cas...
# 1  https://amazon.co.uk/Trek-Cocoa-Oat-Protein-Fl...
# 2  https://amazon.co.uk/Nourish-Cacao-Macaroons-1...
# 3  https://amazon.co.uk/Natural-Protein-Packed-Pa...
# 4  https://amazon.co.uk/HappyHome-Ultimate-Hamper...
#
#                                      final_word_list
# 0  [nakd, fruit, &, nut, bar, variety, pack, -, v...
# 1  [trek, high, protein, flapjack, cocoa, oat, -,...
# 2  [nourish, organic, cacao, coconut, macaroons, ...
# 3  [eat, natural, protein, bars, ,, protein, pack...
# 4  [happyhome, ultimate, hampers, glutenfree, ham...

# %%
porter = PorterStemmer()

# Function to apply stemming
def apply_stemming(word_list):
    return [porter.stem(word) for word in word_list]

# Apply the stemming function to the final word list column
df['final_word_list'] = df['final_word_list'].apply(apply_stemming)

# %%
# Function to remove duplicates from the lists
def remove_duplicates(word_list):
    return list(set(word_list))

# Apply the function to remove duplicates
df['final_word_list'] = df['final_word_list'].apply(remove_duplicates)

# %%
# Function to filter rows based on the words in the specified string
def filter_rows_exclude(input_string):
    input_words = apply_stemming(clean_and_lower(extract_words(preprocess_text(input_string.lower()))))
    filtered_df = df[~df['final_word_list'].apply(lambda x: any(word in x for word in input_words))]
    
    # Reset the index to get new numbers
    filtered_df = filtered_df.reset_index(drop=True)
    
    return filtered_df

def filter_rows_include(input_string):
    input_words = apply_stemming(clean_and_lower(extract_words(preprocess_text(input_string.lower()))))
    filtered_df = df[df['final_word_list'].apply(lambda x: any(word in x for word in input_words))]
    
    # Reset the index to get new numbers
    filtered_df = filtered_df.reset_index(drop=True)
    
    return filtered_df

# Example usage
include_string = "Gluten free protein"
exclude_string = "emulsifier peanuts"
include_result = filter_rows_include(include_string)
exclude_result = filter_rows_exclude(exclude_string)

# %%
include_result.head(3)
# Out:
#                                                title  \
# 0  nakd fruit & nut bar variety pack - vegan - he...
# 1  trek high protein flapjack cocoa oat - gluten ...
# 2  nourish organic cacao coconut macaroons - keto...
#
#                                          ingredients  \
# 0  cocoa orange ingredients: dates 40%, cashews 4...
# 1  gluten free oats (25%), rice syrup, soya prote...
# 2                                                NaN
#
#                                                  url  \
# 0  https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Cas...
# 1  https://amazon.co.uk/Trek-Cocoa-Oat-Protein-Fl...
# 2  https://amazon.co.uk/Nourish-Cacao-Macaroons-1...
#
#                                      final_word_list
# 0  [-, %, date, cashew, ., healthi, snack, oil, s...
# 1  [-, %, *, cane, protein, oat, ., crunchi, flap...
# 2  [-, cacao, free, healthi, snack, dairi, vegan,...

# %%
print(include_result.iloc[0].tolist())
# Out:
# ['nakd fruit & nut bar variety pack - vegan - healthy snack - gluten free - 35g x 18 bars', 'cocoa orange ingredients: dates 40%, cashews 40%, raisins 14%, cocoa 5%, orange oil, natural flavouring. blueberry muffin ingredients: dates 58%, cashews 15%, raisins 15%, almonds 10%, blueberries 2, natural flavouring. salted caramel ingredients: dates 54%, raisins 21%, cashews 12%, peanuts 12%, sea salt 0,4%, natural flavouring. peanut delight ingredients: dates 53%, peanuts 46%, sea salt, natural flavouring. berry delight ingredients: dates 49%, cashews 30%, raisins 17%, raspberries 3%, natural flavouring. cocoa delight ingredients: dates 48%,cashews 30%, raisins 16%, cocoa 6%, natural flavouring.', 'https://amazon.co.uk/Nakd-Mind-Blown-Mixed-Case/dp/B07LFRLNVM/ref=sr_1_1?crid=2G1IQMWSJ30CR&keywords=gluten+free+snacks&qid=1705342939&sprefix=gluten+free+snacks%2Caps%2C271&sr=8-1', ['-', '%', 'date', 'cashew', '.', 'healthi', 'snack', 'oil', 'sea', 'raspberri', '35g', 'vegan', 'delight', 'glutenfre', 'orang', 'raisin', 'flavour', '&', 'natur', ',', 'salt', 'varieti', '0,4', 'almond', 'berri', 'peanut', 'ingredi', 'nut', 'muffin', 'cocoa', 'bar', 'caramel', 'pack', 'fruit', ':', 'nakd', 'blueberri', 'x']]

# %%
exclude_result.head(3)
# Out:
#                                                title ingredients  \
# 0  nourish organic cacao coconut macaroons - keto...         NaN
# 1  happyhome ultimate hampers gluten free hamper ...         NaN
# 2  bon bag - gluten-free fizzy and fizz-free pick...         NaN
#
#                                                  url  \
# 0  https://amazon.co.uk/Nourish-Cacao-Macaroons-1...
# 1  https://amazon.co.uk/HappyHome-Ultimate-Hamper...
# 2  https://amazon.co.uk/Large-Litre-Gluten-Free-S...
#
#                                      final_word_list
# 0  [-, cacao, free, healthi, snack, dairi, vegan,...
# 1  [vegans-contain, free, healthi, snack, bundl, ...
# 2  [-, bag, 800g, pick, ., mix, candi, sweet, ,, ...

# %%
print(exclude_result.iloc[0].tolist())
# Out:
# ['nourish organic cacao coconut macaroons - keto snacks - vegan, gluten free, dairy free healthy snacks made with natural ingredients - 140g (pack of 1)', nan, 'https://amazon.co.uk/Nourish-Cacao-Macaroons-140-g/dp/B07656GYHP/ref=sr_1_3?crid=2G1IQMWSJ30CR&keywords=gluten+free+snacks&qid=1705342939&sprefix=gluten+free+snacks%2Caps%2C271&sr=8-3', ['-', 'cacao', 'free', 'healthi', 'snack', 'dairi', 'vegan', 'glutenfre', 'natur', ',', 'with', '(', 'macaroon', 'ingredi', '140g', 'of', 'pack', 'coconut', ')', 'organ', 'nourish', 'made', 'keto']]

# %%
def filter_rows_both(include_string, exclude_string):
    include_words = apply_stemming(clean_and_lower(extract_words(preprocess_text(include_string.lower()))))
    exclude_words = apply_stemming(clean_and_lower(extract_words(preprocess_text(exclude_string.lower()))))
    
    included_rows = df[df['final_word_list'].apply(lambda x: any(word in x for word in include_words))]
    excluded_rows = df[~df['final_word_list'].apply(lambda x: any(word in x for word in exclude_words))]
    
    # Combine the results
    filtered_df = pd.merge(included_rows, excluded_rows, how='inner', on='title')
    
    # Reset the index to get new numbers
    filtered_df = filtered_df.reset_index(drop=True)
    
    return filtered_df.iloc[:,:4]

# %%
result_both = filter_rows_both("gluten free vegan allergen free", "emulsifier peanuts dairy cashew almond ")
result_both.head(20)
# Out:
#                                                 title  \
# 0   kallo organic belgian milk chocolate rice cake...
# 1   purely plantain chips - low fat plantain crisp...
# 2   kallo beetroot & balsamic veggie cakes, lentil...
# 3   emily - veg crisps - rainbow roots - gluten fr...
# 4   the happy snack company chocolate chickpeas ta...
# 5   trek high protein flapjack original oat - glut...
# 6   kallo protein packed lentil cakes, low fat hea...
# 7   scratch my pork bulk pork crackling - lightly ...
# 8   bear strawberry yoyos - dried fruit rolls - he...
# 9   bear variety pack yoyos - dried fruit rolls - ...
# 10  love corn salt & vinegar crunchy corn snack 45...
# 11  brave crunchy peas: sea salt and vinegar - del...
# 12  cheesies | crunchy cheese keto snack | gouda |...
# 13  love corn bbq crunchy corn snack 115g x 6 bags...
# 14  nibbly wibbly’s - wonderfully cheesy - crunchy...
# 15  idahoan mashed potato pots, bubble and squeak,...
# 16  popworks sweet & salty 28g (case of 18) vegan ...
# 17  airsnax sweet chilli puffed chickpea protein s...
# 18  gusto - crunchy apple crisps with mango juice,...
# 19  love corn salt & vinegar crunchy corn snack 11...
#
#                                         ingredients_x  \
# 0                                                 NaN
# 1                      plantains, sunflower oil, salt
# 2   lentil flour (76%), rapeseed oil, beetroot bal...
# 3   sweet potato, carrot, beetroot, sunflower oil,...
# 4                                                 NaN
# 5   gluten free oats (29%), rice syrup, soya prote...
# 6   lentil flour (48%), corn flour, potato starch,...
# 7                                                 NaN
# 8                         apples, pears, strawberries
# 9   ingredients: apples, pears, strawberries, blac...
# 10  corn, paprika, onion, garlic, sea salt, sunflo...
# 11  yellow split peas, rapeseed oil, sprit vinegar...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  idaho® potatoes (74%), vegetable oils (coconut...
# 16    corn (75%), sunflower oil, cane sugar, sea salt
# 17                                                NaN
# 18  apples, mango juice concentrate, natural aroma...
# 19                                                NaN
#
#                                                 url_x  \
# 0   https://amazon.co.uk/Kallo-Organic-Milk-Chocol...
# 1   https://amazon.co.uk/Purely-Plantain-Chips-Nut...
# 2   https://amazon.co.uk/Kallo-Beetroot-Balsamic-V...
# 3   https://amazon.co.uk/Emily-Veg-Crisps-Rainbow-...
# 4   https://amazon.co.uk/Happy-Snack-Company-Choco...
# 5   https://amazon.co.uk/Trek-Protein-Flapjack-Bar...
# 6   https://amazon.co.uk/Kallo-Protein-Packed-Lent...
# 7   https://amazon.co.uk/Scratch-Pork-Bulk-Crackli...
# 8   https://amazon.co.uk/BEAR-Strawberry-Pure-Frui...
# 9   https://amazon.co.uk/BEAR-Variety-Pack-Yoyos-L...
# 10  https://amazon.co.uk/LOVE-CORN-Vinegar-Roasted...
# 11  https://amazon.co.uk/BRAVE-Roasted-Peas-Delici...
# 12  https://amazon.co.uk/Cheesies-Crunchy-Protein-...
# 13  https://amazon.co.uk/LOVE-CORN-Premium-Crunchy...
# 14  https://amazon.co.uk/Nibbly-Wibblys-Wonderfull...
# 15  https://amazon.co.uk/Idahoan-Mashed-Potato-Bub...
# 16  https://amazon.co.uk/Popworks-Sweet-Salty-Vega...
# 17  https://amazon.co.uk/AIRSNAX-Chickpea-Gluten-F...
# 18  https://amazon.co.uk/GUSTO-Crunchy-Vegetarian-...
# 19  https://amazon.co.uk/LOVE-CORN-Vinegar-Crunchy...
#
#                                     final_word_list_x
# 0   [preserv, artifici, thin, healthi, snack, pack...
# 1   [-, crisp, healthi, snack, altern, sea, oil, n...
# 2   [%, pepper, artifici, season, healthi, 5.7, sn...
# 3   [-, crisp, free, oil, potato, sea, vegan, sunf...
# 4   [portion, 20g, chickpea, tasti, cal, free, sna...
# 5   [-, %, *, protein, oat, flapjack, plant, snack...
# 6   [%, corn, artifici, protein, free, healthi, sn...
# 7   [-, %, bag, rind, protein, food, ., snack, glu...
# 8   [-, fruit, 20g, (, bear, ), pear, roll, health...
# 9   [-, 20g, ., pear, healthi, strawberri, raspber...
# 10  [corn, bag, crisp, crunchi, healthi, snack, al...
# 11  [-, plant-bas, protein, sprit, crunchi, health...
# 12  [bake, %, 20g, bag, chees, protein, free, crun...
# 13  [corn, bag, 115g, bbq, crisp, crunchi, healthi...
# 14  [nibbl, -, bake, corn, chees, wibbl, crunchi, ...
# 15  [preserv, idahoan, %, maltodextrin, pot, minut...
# 16  [%, corn, cane, oil, sea, vegan, sunflow, glut...
# 17  [bag, crisp, protein, healthi, snack, altern, ...
# 18  [-, bake, even, crisp, from, oat, ., crunchi, ...
# 19  [corn, bag, 115g, crisp, crunchi, healthi, sna...

# %%
print(result_both.iloc[20].tolist())
# Out:
# ['gluten free snack bars | creative nature vegan snack bars | berry blend flavour | healthy snacks, lunchbox snacks | top 14 allergen free | 20 x 38g bars', 'gluten free oats, dried fruit (67%)(apricots, cranberries, sultanas, sour cherries, goji berries, mango), chicory fibre, vegetable glycerine, natural flavouring', 'https://amazon.co.uk/Creative-Nature-Goodness-Vegan-Flapjack/dp/B082Q149VR/ref=sr_1_53?crid=2QJW2OV8ZTB2Y&dib=eyJ2IjoiMSJ9.H87tE2j8bdAC9NriA5bvgCnaoISIYIiB0ei3Q1FVbsn8ajMafSvFvurjjVARxLT3Hbwa1qiniLh2SsJlTUPxwSvpHW3qhWaUSyBeOOm0W-6JpFJDFfF3DM7Rl8uYI08VZ6ohsAnXmUeRdJHkhlj2uv6ZZ0lHNpgl6crdczkrpe0y7qB-_Kb2543RTWOJ1xwuasuCjbidJgqMdxapE3C3kt8n3srQdomb6OyM1IoTniI.owVGWbCLWnbDBPWQ_qar8ZrktngmmOyn8X9GMPnvGWo&dib_tag=se&keywords=gluten+free+snacks&qid=1705345458&sprefix=gluten+free+snacks%2Caps%2C734&sr=8-53', ['%', 'allergenfre', 'oat', 'healthi', 'snack', 'chicori', 'vegan', 'creativ', 'glutenfre', 'flavour', 'natur', 'top', ',', 'apricot', 'goji', 'dri', '(', 'cranberri', 'berri', 'blend', 'sultana', 'cherri', 'bar', 'sour', 'glycerin', 'fruit', 'fibr', 'veget', 'x', '|', ')', 'lunchbox', '38g', 'mango']]

# %%
result_both[['title', 'url_x']]
# Out:
#                                                  title  \
# 0    kallo organic belgian milk chocolate rice cake...
# 1    purely plantain chips - low fat plantain crisp...
# 2    kallo beetroot & balsamic veggie cakes, lentil...
# 3    emily - veg crisps - rainbow roots - gluten fr...
# 4    the happy snack company chocolate chickpeas ta...
# ..                                                 ...
# 146  farmgio organic dried apricot 4x (250 g) | cer...
# 147  nugo protein bar, vanilla yogurt, 11g protein,...
# 148  go-low easy wrap keto mix | low carb | high fi...
# 149  pride of india - mung bean plain papadum lenti...
# 150  shores of africa gluten free coconut mango sna...
#
#                                                  url_x
# 0    https://amazon.co.uk/Kallo-Organic-Milk-Chocol...
# 1    https://amazon.co.uk/Purely-Plantain-Chips-Nut...
# 2    https://amazon.co.uk/Kallo-Beetroot-Balsamic-V...
# 3    https://amazon.co.uk/Emily-Veg-Crisps-Rainbow-...
# 4    https://amazon.co.uk/Happy-Snack-Company-Choco...
# ..                                                 ...
# 146  https://amazon.co.uk/Farmgio-Certified-Agricul...
# 147  https://amazon.co.uk/Nugo-Nutrition-NuGo-Vanil...
# 148  https://amazon.co.uk/GO-LOW-Grain-Diabetic-fri...
# 149  https://amazon.co.uk/Pride-India-Papadum-Lenti...
# 150  https://amazon.co.uk/Shores-Africa-Gluten-Coco...
#
# [151 rows x 2 columns]
